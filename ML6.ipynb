# %% [markdown]
# <a href="https://colab.research.google.com/github/leofanci/ML_works/blob/main/ML6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.) Preprocess your data into scaled input variables and an output variable

# %%
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt
import numpy as np
import datetime
import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
drive.mount('/content/gdrive/', force_remount = True)
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv("/content/gdrive/MyDrive/ML/CLV.csv")

# %%
df
# Out:
#       Unnamed: 0  Customer Lifetime Value  Income  Number of Policies  \
# 0              0              2763.519279   56274                   1
# 1              1              6979.535903       0                   8
# 2              2             12887.431650   48767                   2
# 3              3              7645.861827       0                   7
# 4              4              2813.692575   43836                   1
# ...          ...                      ...     ...                 ...
# 9129        9129             23405.987980   71941                   2
# 9130        9130              3096.511217   21604                   1
# 9131        9131              8163.890428       0                   2
# 9132        9132              7524.442436   21941                   3
# 9133        9133              2611.836866       0                   1
#
#       Total Claim Amount  Months Since Last Claim  Vehicle Size_Large  \
# ...

# %%
X = df.drop(["Unnamed: 0","Customer Lifetime Value"], axis =1 )
y = df['Customer Lifetime Value']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .3)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # 2.) Run a GridSearch CV on at least 10 possible combinations of hyper parameters

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV

# %%
clf = MLPRegressor()

params = {
    "hidden_layer_sizes": [(10,), (20,5,), (10, 10), (20, 20)], 
    "activation" : ['relu','logistic'],
    'alpha': [0.0001, 0.001, 0.01]
}

# %%
grid = GridSearchCV(clf, params, cv = 5)
grid.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %% [markdown]
# # 3.) Train a model with the optimal solution from GridSearch

# %%
grid.best_score_
# Out:
# 0.05596242873588404

# %%
grid.best_params_
# Out:
# {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (20, 20)}

# %%
MLPR = MLPRegressor(**grid.best_params_)

# %%
MLPR.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPRegressor(alpha=0.001, hidden_layer_sizes=(20, 20))

# %% [markdown]
# # 4.) What are the in-sample and out of sample MSEs

# %%
from sklearn.metrics import mean_squared_error

# %%
y_train_pred = MLPR.predict(X_train)
in_sample_mse = mean_squared_error(y_train, y_train_pred)

# %%
y_test_pred = MLPR.predict(X_test)
out_of_sample_mse = mean_squared_error(y_test, y_test_pred)

# %%
print("In-sample MSE: ", in_sample_mse)
print("Out-of-sample MSE: ", out_of_sample_mse)
# Out:
# In-sample MSE:  44824979.2437561
# Out-of-sample MSE:  40018985.8465841

# %% [markdown]
# # 5.) Build a Keras with the architecture defined by GridSearchCV

# %%
import keras.models
from keras.optimizers import Adam 
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(20, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(1))

# %%
model.compile(loss='mse', optimizer=Adam(lr=0.01))
model.fit(X_train, y_train, batch_size=33, epochs=10)
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/10
# 194/194 [==============================] - 1s 2ms/step - loss: 86378392.0000
# Epoch 2/10
# 194/194 [==============================] - 0s 1ms/step - loss: 47488424.0000
# Epoch 3/10
# 194/194 [==============================] - 0s 2ms/step - loss: 45662396.0000
# Epoch 4/10
# 194/194 [==============================] - 0s 1ms/step - loss: 45373092.0000
# Epoch 5/10
# 194/194 [==============================] - 0s 1ms/step - loss: 45188404.0000
# Epoch 6/10
# 194/194 [==============================] - 0s 1ms/step - loss: 45055804.0000
# Epoch 7/10
# 194/194 [==============================] - 0s 1ms/step - loss: 44989632.0000
# Epoch 8/10
# 194/194 [==============================] - 0s 2ms/step - loss: 44985656.0000
# Epoch 9/10
# ...

# %% [markdown]
# # 6.) Make two visualizations of your NN using “plot_model” and “ann_viz”

# %%
from keras.utils import plot_model
from ann_visualizer.visualize import ann_viz

# %%
plot_model(model, to_file="model_plot.png", show_shapes=True, show_layer_names=True)

# %%
ann_viz(model, view=True, filename="annViz.gv")

# %%
import subprocess

# %%
subprocess.call(['dot', '-Tpng', 'annViz.gv', '-o', 'neural_network.png'])
# Out:
# 0

# %%
Image(filename='neural_network.png')
